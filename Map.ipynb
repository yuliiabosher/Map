# %% [markdown]
# <a href="https://colab.research.google.com/github/yuliiabosher/Map/blob/main/Map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas
# !pip install pyogrio
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (24.0)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.4)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2024.2.2)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.25.2)
# Requirement already satisfied: pyogrio in /usr/local/lib/python3.10/dist-packages (0.8.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyogrio) (2024.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyogrio) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from pyogrio) (24.0)

# %%
import geopandas as gpd
import pandas as pd
import pyogrio
import folium

# %%
def read_shape_file(file):
  district = gpd.read_file(file, engine="pyogrio", columns=['name','type', 'geometry'], where="type='military'", layer=0)
  return district

# %%
central_district = read_shape_file("https://download.geofabrik.de/russia/central-fed-district-latest-free.shp.zip")
display(central_district)
# Out:
#                                                    name      type  \
# 0     Объединённый военный комиссариат Тушинского ра...  military
# 1                                                  None  military
# 2                                                  None  military
# 3                                                  None  military
# 4                                                  None  military
# ...                                                 ...       ...
# 1464                                               None  military
# 1465                                               None  military
# 1466                                               None  military
# 1467                                               None  military
# 1468                                               None  military
#
#                                                geometry
# 0     POLYGON ((37.48063 55.80116, 37.48084 55.80135...
# 1     POLYGON ((37.45094 55.83278, 37.45102 55.83328...
# 2     POLYGON ((39.16530 51.62406, 39.16544 51.62420...
# 3     POLYGON ((39.16468 51.62427, 39.16481 51.62442...
# 4     POLYGON ((39.17135 51.61535, 39.17235 51.61540...
# ...                                                 ...
# 1464  POLYGON ((35.41758 51.04139, 35.41766 51.04141...
# 1465  POLYGON ((35.41636 51.04103, 35.41639 51.04112...
# 1466  POLYGON ((35.41517 51.03990, 35.41517 51.03997...
# 1467  POLYGON ((35.41575 51.03972, 35.41581 51.03977...
# 1468  POLYGON ((35.44322 50.97077, 35.44326 50.97077...
#
# [1469 rows x 3 columns]

# %%
occupied_crimea = read_shape_file('https://download.geofabrik.de/russia/crimean-fed-district-latest-free.shp.zip')
display(occupied_crimea)
# Out:
#                                                 name      type  \
# 0  Штаб Краснознамённого Черноморского флота ВМФ ...  military
# 1                                               None  military
# 2                                               None  military
#
#                                             geometry
# 0  POLYGON ((33.52354 44.61299, 33.52355 44.61299...
# 1  POLYGON ((34.27575 46.05076, 34.27576 46.05079...
# 2  POLYGON ((34.27555 46.05078, 34.27556 46.05082...

# %%
far_eastern_district = read_shape_file('https://download.geofabrik.de/russia/far-eastern-fed-district-latest-free.shp.zip')
display(far_eastern_district)
# Out:
#            name      type                                           geometry
# 0          None  military  POLYGON ((142.74976 46.94644, 142.74996 46.946...
# 1          None  military  POLYGON ((142.74922 46.94711, 142.74939 46.947...
# 2          None  military  POLYGON ((142.74973 46.94705, 142.74991 46.947...
# 3          None  military  POLYGON ((158.55027 53.13375, 158.55042 53.133...
# 4          None  military  POLYGON ((142.74977 46.94733, 142.74984 46.947...
# 5          None  military  POLYGON ((158.55005 53.13401, 158.55015 53.134...
# 6          None  military  POLYGON ((158.54895 53.13398, 158.54899 53.134...
# 7  Охрана моста  military  POLYGON ((137.02149 50.47192, 137.02187 50.472...
# 8          None  military  MULTIPOLYGON (((137.02117 50.47211, 137.02121 ...

# %%
north_caucasus_district = read_shape_file('https://download.geofabrik.de/russia/north-caucasus-fed-district-latest-free.shp.zip')
display(north_caucasus_district)
# Out:
#      name      type                                           geometry
# 0    None  military  POLYGON ((42.98370 43.20634, 42.98385 43.20636...
# 1    None  military  POLYGON ((42.98358 43.20646, 42.98372 43.20647...
# 2    None  military  POLYGON ((42.98350 43.20636, 42.98365 43.20637...
# 3    None  military  POLYGON ((42.53426 43.24849, 42.53429 43.24868...
# 4    None  military  POLYGON ((42.53543 43.24826, 42.53549 43.24864...
# ..    ...       ...                                                ...
# 302  None  military  POLYGON ((44.55542 43.76716, 44.55542 43.76721...
# 303  None  military  POLYGON ((44.55785 43.76989, 44.55788 43.77006...
# 304  None  military  POLYGON ((44.55755 43.77026, 44.55756 43.77031...
# 305  None  military  POLYGON ((46.38258 41.90372, 46.38266 41.90376...
# 306  None  military  POLYGON ((43.57940 43.62511, 43.57948 43.62513...
#
# [307 rows x 3 columns]

# %%
northwestern_district = read_shape_file('https://download.geofabrik.de/russia/northwestern-fed-district-latest-free.shp.zip')
display(northwestern_district)
# Out:
#                                        name      type  \
# 0   Военный комиссариат Фрунзенского района  military
# 1                          Старый военкомат  military
# 2                                      None  military
# 3                                      None  military
# 4                                      None  military
# 5                    сгоревший Дом Офицеров  military
# 6                          Бывший госпиталь  military
# 7                       Заброшенные казармы  military
# 8                       сгоревшая Кочегарка  military
# 9                                      None  military
# 10                                     None  military
# 11                                     None  military
# 12                                     None  military
# 13                                     None  military
# 14                                     None  military
# 15                                     None  military
# 16                                     None  military
# 17                              комендатура  military
# 18                                     None  military
# 19                      Заброшенные казармы  military
# 20               Бывшая солдатская столовая  military
# 21                                     None  military
# 22                                     None  military
# 23                                КПП "КЭЧ"  military
# 24                                     None  military
# 25                                     None  military
# 26                             Райвоенкомат  military
# 27                                     None  military
# 28                                     None  military
# 29                                     None  military
# 30        Стрелковая команда станции Микунь  military
# 31                                     None  military
# 32                                     None  military
# 33                                     None  military
# 34                                     None  military
# 35                                     None  military
# 36                                     None  military
# 37                                     None  military
# 38                                     None  military
# 39                                     None  military
# 40                                     None  military
#
#                                              geometry
# 0   POLYGON ((30.40960 59.86227, 30.40972 59.86248...
# 1   POLYGON ((32.44211 67.16977, 32.44259 67.17000...
# 2   POLYGON ((33.41088 69.07820, 33.41113 69.07824...
# 3   POLYGON ((33.41137 69.07773, 33.41201 69.07790...
# 4   POLYGON ((33.41150 69.07825, 33.41171 69.07831...
# 5   POLYGON ((32.42309 67.16715, 32.42315 67.16732...
# 6   POLYGON ((32.42226 67.17005, 32.42250 67.17052...
# 7   POLYGON ((32.42667 67.16693, 32.42673 67.16712...
# 8   POLYGON ((32.42299 67.16847, 32.42303 67.16856...
# 9   POLYGON ((32.41788 67.17131, 32.41813 67.17199...
# 10  POLYGON ((32.42363 67.17297, 32.42380 67.17312...
# 11  POLYGON ((32.42620 67.17257, 32.42637 67.17272...
# 12  POLYGON ((32.42835 67.17223, 32.42925 67.17278...
# 13  POLYGON ((32.42442 67.17355, 32.42474 67.17386...
# 14  POLYGON ((32.42639 67.17327, 32.42663 67.17347...
# 15  POLYGON ((32.42587 67.17397, 32.42605 67.17413...
# 16  POLYGON ((32.42679 67.17358, 32.42689 67.17366...
# 17  POLYGON ((32.41840 67.16714, 32.41844 67.16722...
# 18  POLYGON ((32.41750 67.17072, 32.41763 67.17111...
# 19  POLYGON ((32.41957 67.17117, 32.41986 67.17188...
# 20  POLYGON ((32.41891 67.17225, 32.41896 67.17239...
# 21  POLYGON ((32.42989 67.17290, 32.42994 67.17293...
# 22  POLYGON ((32.42908 67.17327, 32.42977 67.17367...
# 23  POLYGON ((32.42548 67.17266, 32.42565 67.17280...
# 24  POLYGON ((40.35138 62.75703, 40.35190 62.75721...
# 25  POLYGON ((40.35262 62.75629, 40.35319 62.75647...
# 26  POLYGON ((30.12103 61.03584, 30.12122 61.03587...
# 27  POLYGON ((50.79129 61.66467, 50.79200 61.66474...
# 28  POLYGON ((30.65553 60.18020, 30.65560 60.18027...
# 29  POLYGON ((29.11468 59.89449, 29.11508 59.89460...
# 30  POLYGON ((50.07668 62.35941, 50.07693 62.35954...
# 31  POLYGON ((50.79177 61.66565, 50.79207 61.66568...
# 32  POLYGON ((29.09955 59.88021, 29.10005 59.88070...
# 33  POLYGON ((29.09909 59.87946, 29.09959 59.88000...
# 34  POLYGON ((29.10083 59.88016, 29.10123 59.88056...
# 35  POLYGON ((29.11511 59.88600, 29.11550 59.88627...
# 36  POLYGON ((29.11441 59.88577, 29.11466 59.88595...
# 37  POLYGON ((29.09902 59.88102, 29.09969 59.88175...
# 38  POLYGON ((29.09970 59.87920, 29.10013 59.87967...
# 39  POLYGON ((30.62144 60.14739, 30.62153 60.14744...
# 40  POLYGON ((30.48764 60.33932, 30.48771 60.33939...

# %%
siberian_district = read_shape_file('https://download.geofabrik.de/russia/siberian-fed-district-latest-free.shp.zip')
display(siberian_district)
# Out:
#                name      type  \
# 0  Коммандный пункт  military
# 1              None  military
# 2              None  military
# 3              None  military
# 4              None  military
#
#                                             geometry
# 0  POLYGON ((83.20938 54.89333, 83.20941 54.89336...
# 1  POLYGON ((74.32342 56.89968, 74.32365 56.89972...
# 2  POLYGON ((74.31976 56.89903, 74.32082 56.89920...
# 3  POLYGON ((74.32187 56.89915, 74.32247 56.89929...
# 4  POLYGON ((74.32129 56.89890, 74.32188 56.89903...

# %%
south_district = read_shape_file('https://download.geofabrik.de/russia/south-fed-district-latest-free.shp.zip')
display(south_district)
# Out:
#       name      type                                           geometry
# 0     None  military  POLYGON ((39.63640 47.26170, 39.64092 47.26346...
# 1     None  military  POLYGON ((39.66360 47.26513, 39.66386 47.26516...
# 2     None  military  POLYGON ((39.65726 47.26974, 39.65739 47.26980...
# 3     None  military  POLYGON ((39.65691 47.26910, 39.65753 47.26934...
# 4     None  military  POLYGON ((39.65669 47.26948, 39.65683 47.26953...
# ...    ...       ...                                                ...
# 1305  None  military  POLYGON ((39.71053 47.05289, 39.71053 47.05295...
# 1306  None  military  POLYGON ((39.71012 47.05277, 39.71012 47.05295...
# 1307  None  military  POLYGON ((40.00757 48.27842, 40.00767 48.27845...
# 1308  None  military  POLYGON ((40.00793 48.27852, 40.00831 48.27862...
# 1309  None  military  POLYGON ((40.00814 48.27891, 40.00864 48.27892...
#
# [1310 rows x 3 columns]

# %%
ural_district = read_shape_file('https://download.geofabrik.de/russia/ural-fed-district-latest-free.shp.zip')
display(ural_district)
# Out:
#                     name      type  \
# 0   Караульное помещение  military
# 1                   None  military
# 2                   None  military
# 3                   None  military
# 4                   None  military
# 5                   None  military
# 6                   None  military
# 7                   None  military
# 8                   None  military
# 9                   None  military
# 10           Пост охраны  military
# 11  Караульное помещение  military
#
#                                              geometry
# 0   POLYGON ((60.11170 57.96638, 60.11175 57.96645...
# 1   POLYGON ((60.07020 57.96717, 60.07040 57.96722...
# 2   POLYGON ((60.06972 57.96672, 60.07063 57.96696...
# 3   POLYGON ((60.06581 57.96595, 60.06609 57.96602...
# 4   POLYGON ((60.06647 57.96626, 60.06686 57.96637...
# 5   POLYGON ((60.69382 57.07307, 60.69393 57.07316...
# 6   POLYGON ((60.69515 57.07268, 60.69519 57.07273...
# 7   POLYGON ((60.69607 57.07240, 60.69611 57.07244...
# 8   POLYGON ((60.69270 57.07215, 60.69280 57.07225...
# 9   POLYGON ((60.69441 57.07162, 60.69451 57.07172...
# 10  POLYGON ((60.14717 57.94015, 60.14724 57.94018...
# 11  POLYGON ((60.00483 56.81364, 60.00494 56.81377...

# %%
volga_district = read_shape_file('https://download.geofabrik.de/russia/volga-fed-district-latest-free.shp.zip')
display(volga_district)
# Out:
#     name      type                                           geometry
# 0   None  military  POLYGON ((53.37761 57.87585, 53.37780 57.87591...
# 1   None  military  POLYGON ((49.30739 59.08499, 49.30801 59.08510...
# 2   None  military  POLYGON ((49.61026 58.58076, 49.61067 58.58091...
# 3   None  military  POLYGON ((53.26917 57.86069, 53.26933 57.86136...
# 4   None  military  POLYGON ((53.26677 57.85884, 53.26684 57.85916...
# 5   None  military  POLYGON ((53.26726 57.85835, 53.26732 57.85863...
# 6   None  military  POLYGON ((53.27037 57.86018, 53.27061 57.86129...
# 7   None  military  POLYGON ((53.28312 57.85987, 53.28323 57.86039...
# 8   None  military  POLYGON ((45.99806 51.18737, 45.99806 51.18740...
# 9   None  military  POLYGON ((53.28248 57.86146, 53.28251 57.86164...
# 10  None  military  POLYGON ((53.28207 57.85993, 53.28218 57.86045...
# 11  None  military  POLYGON ((53.28098 57.86000, 53.28109 57.86052...
# 12  None  military  POLYGON ((53.27992 57.86007, 53.28003 57.86059...
# 13  None  military  POLYGON ((53.27882 57.86014, 53.27893 57.86067...
# 14  None  military  POLYGON ((53.27773 57.86021, 53.27784 57.86073...
# 15  None  military  POLYGON ((53.27665 57.86028, 53.27676 57.86080...
# 16  None  military  POLYGON ((53.27557 57.86036, 53.27568 57.86088...
# 17  None  military  POLYGON ((53.27450 57.86042, 53.27461 57.86094...
# 18  None  military  POLYGON ((53.28421 57.85980, 53.28431 57.86032...
# 19  None  military  POLYGON ((53.28527 57.85973, 53.28538 57.86025...
# 20  None  military  POLYGON ((53.28638 57.85967, 53.28649 57.86019...
# 21  None  military  POLYGON ((53.28744 57.85959, 53.28755 57.86011...
# 22  None  military  POLYGON ((53.28854 57.85953, 53.28865 57.86005...
# 23  None  military  POLYGON ((53.28962 57.85946, 53.28973 57.85999...
# 24  None  military  POLYGON ((53.27416 57.85873, 53.27429 57.85936...
# 25  None  military  POLYGON ((53.27522 57.85866, 53.27535 57.85929...
# 26  None  military  POLYGON ((53.27630 57.85859, 53.27643 57.85921...
# 27  None  military  POLYGON ((53.27737 57.85852, 53.27750 57.85914...
# 28  None  military  POLYGON ((53.27847 57.85846, 53.27860 57.85908...
# 29  None  military  POLYGON ((53.27953 57.85839, 53.27966 57.85901...
# 30  None  military  POLYGON ((53.28064 57.85832, 53.28077 57.85895...
# 31  None  military  POLYGON ((53.28172 57.85826, 53.28185 57.85888...
# 32  None  military  POLYGON ((53.28386 57.85812, 53.28399 57.85874...
# 33  None  military  POLYGON ((53.28492 57.85805, 53.28505 57.85867...
# 34  None  military  POLYGON ((53.28599 57.85798, 53.28612 57.85860...
# 35  None  military  POLYGON ((53.28709 57.85790, 53.28722 57.85853...
# 36  None  military  POLYGON ((53.28925 57.85779, 53.28938 57.85841...
# 37  None  military  POLYGON ((49.19673 59.03262, 49.19678 59.03264...

# %%
kaliningrad_district = read_shape_file('https://download.geofabrik.de/russia/kaliningrad-latest-free.shp.zip')
display(kaliningrad_district)
# Out:
# Empty GeoDataFrame
# Columns: [name, type, geometry]
# Index: []

# %%
districts_combined = pd.concat([central_district, occupied_crimea, far_eastern_district, \
north_caucasus_district, northwestern_district, siberian_district, south_district, ural_district, volga_district, kaliningrad_district])
display(districts_combined)
# Out:
#                                                  name      type  \
# 0   Объединённый военный комиссариат Тушинского ра...  military
# 1                                                None  military
# 2                                                None  military
# 3                                                None  military
# 4                                                None  military
# ..                                                ...       ...
# 33                                               None  military
# 34                                               None  military
# 35                                               None  military
# 36                                               None  military
# 37                                               None  military
#
#                                              geometry
# 0   POLYGON ((37.48063 55.80116, 37.48084 55.80135...
# 1   POLYGON ((37.45094 55.83278, 37.45102 55.83328...
# 2   POLYGON ((39.16530 51.62406, 39.16544 51.62420...
# 3   POLYGON ((39.16468 51.62427, 39.16481 51.62442...
# 4   POLYGON ((39.17135 51.61535, 39.17235 51.61540...
# ..                                                ...
# 33  POLYGON ((53.28492 57.85805, 53.28505 57.85867...
# 34  POLYGON ((53.28599 57.85798, 53.28612 57.85860...
# 35  POLYGON ((53.28709 57.85790, 53.28722 57.85853...
# 36  POLYGON ((53.28925 57.85779, 53.28938 57.85841...
# 37  POLYGON ((49.19673 59.03262, 49.19678 59.03264...
#
# [3194 rows x 3 columns]

# %%
districts_combined_street_map = folium.Map(location = [56.0184, 92.8672], zoom_start=10)
folium.GeoJson(military_objects.geometry).add_to(districts_combined_street_map)
display(districts_combined_street_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1afdbbd44089de0a33ac2f84389b1085 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1afdbbd44089de0a33ac2f84389b1085&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1afdbbd44089de0a33ac2f84389b1085 = L.map(
#                 &quot;map_1afdbbd44089de0a33ac2f84389b1085&quot;,
#                 {
#                     center: [56.0184, 92.8672],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a8f370efc672985d00cd4beea2452735 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1afdbbd44089de0a33ac2f84389b1085);
#
#
#
#         function geo_json_b4d85789c74d381b130c6fc0ae22cb44_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b4d85789c74d381b130c6fc0ae22cb44 = L.geoJson(null, {
#                 onEachFeature: geo_json_b4d85789c74d381b130c6fc0ae22cb44_onEachFeature,
#
#         });
#
#         function geo_json_b4d85789c74d381b130c6fc0ae22cb44_add (data) {
#             geo_json_b4d85789c74d381b130c6fc0ae22cb44
#                 .addData(data)
#                 .addTo(map_1afdbbd44089de0a33ac2f84389b1085);
#         }
#             geo_json_b4d85789c74d381b130c6fc0ae22cb44_add({&quot;bbox&quot;: [29.0990177, 41.9036848, 158.5506755, 69.0783054], &quot;features&quot;: [{&quot;bbox&quot;: [37.4806306, 55.8009568, 37.4814428, 55.8013536], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[37.4806306, 55.8011602], [37.4808424, 55.8013536], [37.4810354, 55.8012869], [37.4809371, 55.8011971], [37.4809545, 55.801191], [37.4811513, 55.801123], [37.4812617, 55.8012238], [37.4814428, 55.8011612], [37.481219, 55.8009568], [37.4806306, 55.8011602]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [37.4509386, 55.8326488, 37.453191, 55.8332776], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[37.4509386, 55.832779], [37.4510248, 55.8332776], [37.4512718, 55.8332633], [37.451216, 55.8329019], [37.452028, 55.8328536], [37.4528801, 55.8328028], [37.4529356, 55.8331565], [37.453191, 55.8331428], [37.4531035, 55.8326488], [37.4522386, 55.8326997], [37.4522348, 55.8326776], [37.4519958, 55.8326905], [37.4517744, 55.8327026], [37.4517797, 55.8327333], [37.4509386, 55.832779]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [39.1653047, 51.6238823, 39.1659153, 51.6241959], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[39.1653047, 51.6240564], [39.1654362, 51.6241959], [39.1659153, 51.6240218], [39.1657837, 51.6238823], [39.1653047, 51.6240564]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [39.1646798, 51.6241006, 39.1653121, 51.6244222], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[39.1646798, 51.6242704], [39.164814, 51.6244222], [39.1653121, 51.6242524], [39.1651778, 51.6241006], [39.1646798, 51.6242704]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [39.1713464, 51.6151927, 39.1723677, 51.6154006], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[39.1713464, 51.6153495], [39.1723469, 51.6154006], [39.1723677, 51.6152437], [39.1713672, 51.6151927], [39.1713464, 51.6153495]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [39.171283, 51.6155608, 39.1723619, 51.6159521], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[39.171283, 51.615896], [39.1723147, 51.6159521], [39.1723619, 51.6156168], [39.1713302, 51.6155608], [39.171283, 51.615896]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [39.1699236, 51.6154955, 39.171024, 51.6158707], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[39.1699236, 51.6158155], [39.1709807, 51.6158707], [39.171024, 51.6155507], [39.1699669, 51.6154955], [39.1699236, 51.6158155]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [39.1698491, 51.6160444, 39.1709443, 51.6164328], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[39.1698491, 51.6163728], [39.1708954, 51.6164328], [39.1709443, 51.6161044], [39.169898, 51.6160444], [39.1698491, 51.6163728]]], &quot;type&quot;: &quot;P

# %%
central_district_military_buildings['center'] = [x.geometry.centroid for i, x in central_district_military_buildings.iterrows()]
display(central_district_military_buildings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-0f6bee8cf4bb> in <cell line: 1>()
# ----> 1 central_district_military_buildings['center'] = [x.geometry.centroid for i, x in central_district_military_buildings.iterrows()]
#       2 display(central_district_military_buildings)
#
# NameError: name 'central_district_military_buildings' is not defined

# %%
central_district_military_buildings['location'] = [(row.center.y, row.center.x) for index, row in central_district_military_buildings.iterrows()]
central_district_military_buildings

# %%
for index, row in central_district_military_buildings.iterrows():
  location = [row['location'][0], row['location'][1]]
  popup = f"<strong>{row['name']}</strong>"
  marker = folium.Marker(location=location, popup=popup)
  marker.add_to(central_district_street_map)
display(central_district_street_map)

# %%
kaliningrad_district = gpd.read_file('https://download.geofabrik.de/russia/kaliningrad-latest-free.shp.zip')

# %%
building_types_kaliningrad = kaliningrad_district['type'].unique()
display(building_types_kaliningrad)
kaliningrad_ships = kaliningrad_district[kaliningrad_district['type']=='ship']
display(kaliningrad_ships)
kaliningrad_transformer_tower = kaliningrad_district[kaliningrad_district['type']=='transformer_tower']
display(kaliningrad_transformer_tower)
kaliningrad_gasometers = kaliningrad_district[kaliningrad_district['type']=='gasometer']
display(kaliningrad_gasometers)
kaliningrad_manufacture = kaliningrad_district[kaliningrad_district['type']=='manufacture']
display(kaliningrad_manufacture)
kaliningrad_tower = kaliningrad_district[kaliningrad_district['type']=='tower']
display(kaliningrad_tower)
kaliningrad_industrial = kaliningrad_district[kaliningrad_district['type']=='industrial']
display(kaliningrad_industrial)

# %%
kaliningrad_street_map = folium.Map(location = [54.715424, 20.509207], zoom_start=11)
folium.GeoJson(kaliningrad_industrial.geometry).add_to(kaliningrad_street_map)
display(kaliningrad_street_map)
