# %% [markdown]
# <a href="https://colab.research.google.com/github/yuliiabosher/Map/blob/main/Map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas
# !pip install pyogrio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 40.4 MB/s eta 0:00:00
# ...

# %%
import geopandas as gpd
import pyogrio
import folium

# %%
def read_shape_file(file):
  district = gpd.read_file(file, engine="pyogrio", columns=['name','type', 'geometry'])
  return district

# %%
central_district = read_shape_file("https://download.geofabrik.de/russia/central-fed-district-latest-free.shp.zip")
display(central_district)
# Out:
# /usr/local/lib/python3.10/dist-packages/pyogrio/geopandas.py:252: UserWarning: More than one layer found in 'central-fed-district-latest-free.shp.zip': 'gis_osm_buildings_a_free_1' (default), 'gis_osm_landuse_a_free_1', 'gis_osm_natural_a_free_1', 'gis_osm_natural_free_1', 'gis_osm_places_a_free_1', 'gis_osm_places_free_1', 'gis_osm_pofw_a_free_1', 'gis_osm_pofw_free_1', 'gis_osm_pois_a_free_1', 'gis_osm_pois_free_1', 'gis_osm_railways_free_1', 'gis_osm_roads_free_1', 'gis_osm_traffic_a_free_1', 'gis_osm_traffic_free_1', 'gis_osm_transport_a_free_1', 'gis_osm_transport_free_1', 'gis_osm_water_a_free_1', 'gis_osm_waterways_free_1'. Specify layer parameter to avoid this warning.
#   result = read_func(
#                                name     type  \
# 0                              None  garages
# 1                        МЕГА Химки   retail
# 2                             Metro   retail
# 3        Торговый центр "Капитолий"   retail
# 4                         МТК ГРАНД   retail
# ...

# %%
occupied_crimea = read_shape_file('https://download.geofabrik.de/russia/crimean-fed-district-latest-free.shp.zip')
display(occupied_crimea)
# Out:
# /usr/local/lib/python3.10/dist-packages/pyogrio/geopandas.py:252: UserWarning: More than one layer found in 'crimean-fed-district-latest-free.shp.zip': 'gis_osm_buildings_a_free_1' (default), 'gis_osm_landuse_a_free_1', 'gis_osm_natural_a_free_1', 'gis_osm_natural_free_1', 'gis_osm_places_a_free_1', 'gis_osm_places_free_1', 'gis_osm_pofw_a_free_1', 'gis_osm_pofw_free_1', 'gis_osm_pois_a_free_1', 'gis_osm_pois_free_1', 'gis_osm_railways_free_1', 'gis_osm_roads_free_1', 'gis_osm_traffic_a_free_1', 'gis_osm_traffic_free_1', 'gis_osm_transport_a_free_1', 'gis_osm_transport_free_1', 'gis_osm_water_a_free_1', 'gis_osm_waterways_free_1'. Specify layer parameter to avoid this warning.
#   result = read_func(
#                name    type                                           geometry
# 0              None    None  POLYGON ((35.41496 45.32753, 35.41501 45.32758...
# 1              None    None  POLYGON ((35.41507 45.32777, 35.41517 45.32786...
# ...

# %%
far_eastern_district = read_shape_file('https://download.geofabrik.de/russia/far-eastern-fed-district-latest-free.shp.zip')
display(far_eastern_district)
# Out:
# /usr/local/lib/python3.10/dist-packages/pyogrio/geopandas.py:252: UserWarning: More than one layer found in 'far-eastern-fed-district-latest-free.shp.zip': 'gis_osm_buildings_a_free_1' (default), 'gis_osm_landuse_a_free_1', 'gis_osm_natural_a_free_1', 'gis_osm_natural_free_1', 'gis_osm_places_a_free_1', 'gis_osm_places_free_1', 'gis_osm_pofw_a_free_1', 'gis_osm_pofw_free_1', 'gis_osm_pois_a_free_1', 'gis_osm_pois_free_1', 'gis_osm_railways_free_1', 'gis_osm_roads_free_1', 'gis_osm_traffic_a_free_1', 'gis_osm_traffic_free_1', 'gis_osm_transport_a_free_1', 'gis_osm_transport_free_1', 'gis_osm_water_a_free_1', 'gis_osm_waterways_free_1'. Specify layer parameter to avoid this warning.
#   result = read_func(
#                                                       name  type  \
# 0                                                    Океан  None
# 1                                           Морской Вокзал  None
# 2        Приморский драматический театр имени Максима Г...  None
# ...

# %%
north_caucasus_district = read_shape_file('https://download.geofabrik.de/russia/north-caucasus-fed-district-latest-free.shp.zip')
display(north_caucasus_district)
# Out:
# /usr/local/lib/python3.10/dist-packages/pyogrio/geopandas.py:252: UserWarning: More than one layer found in 'north-caucasus-fed-district-latest-free.shp.zip': 'gis_osm_buildings_a_free_1' (default), 'gis_osm_landuse_a_free_1', 'gis_osm_natural_a_free_1', 'gis_osm_natural_free_1', 'gis_osm_places_a_free_1', 'gis_osm_places_free_1', 'gis_osm_pofw_a_free_1', 'gis_osm_pofw_free_1', 'gis_osm_pois_a_free_1', 'gis_osm_pois_free_1', 'gis_osm_railways_free_1', 'gis_osm_roads_free_1', 'gis_osm_traffic_a_free_1', 'gis_osm_traffic_free_1', 'gis_osm_transport_a_free_1', 'gis_osm_transport_free_1', 'gis_osm_water_a_free_1', 'gis_osm_waterways_free_1'. Specify layer parameter to avoid this warning.
#   result = read_func(
#          name        type                                           geometry
# 0         БТА        None  POLYGON ((41.44040 43.64667, 41.44041 43.64675...
# 1        None        None  POLYGON ((40.79185 43.58217, 40.79200 43.58228...
# ...

# %%
northwestern_district = read_shape_file('https://download.geofabrik.de/russia/northwestern-fed-district-latest-free.shp.zip')
display(northwestern_district)
# Out:
# /usr/local/lib/python3.10/dist-packages/pyogrio/geopandas.py:252: UserWarning: More than one layer found in 'northwestern-fed-district-latest-free.shp.zip': 'gis_osm_buildings_a_free_1' (default), 'gis_osm_landuse_a_free_1', 'gis_osm_natural_a_free_1', 'gis_osm_natural_free_1', 'gis_osm_places_a_free_1', 'gis_osm_places_free_1', 'gis_osm_pofw_a_free_1', 'gis_osm_pofw_free_1', 'gis_osm_pois_a_free_1', 'gis_osm_pois_free_1', 'gis_osm_railways_free_1', 'gis_osm_roads_free_1', 'gis_osm_traffic_a_free_1', 'gis_osm_traffic_free_1', 'gis_osm_transport_a_free_1', 'gis_osm_transport_free_1', 'gis_osm_water_a_free_1', 'gis_osm_waterways_free_1'. Specify layer parameter to avoid this warning.
#   result = read_func(
#                   name        type  \
# 0                 None        None
# 1        форт Тотлебен        None
# 2         форт Обручев        None
# 3                 Мега      retail
# 4                Лента       store
# ...                ...         ...
# ...

# %%
siberial_district = read_shape_file('https://download.geofabrik.de/russia/siberian-fed-district-latest-free.shp.zip')
display(siberial_district)
# Out:
# /usr/local/lib/python3.10/dist-packages/pyogrio/geopandas.py:252: UserWarning: More than one layer found in 'siberian-fed-district-latest-free.shp.zip': 'gis_osm_buildings_a_free_1' (default), 'gis_osm_landuse_a_free_1', 'gis_osm_natural_a_free_1', 'gis_osm_natural_free_1', 'gis_osm_places_a_free_1', 'gis_osm_places_free_1', 'gis_osm_pofw_a_free_1', 'gis_osm_pofw_free_1', 'gis_osm_pois_a_free_1', 'gis_osm_pois_free_1', 'gis_osm_railways_free_1', 'gis_osm_roads_free_1', 'gis_osm_traffic_a_free_1', 'gis_osm_traffic_free_1', 'gis_osm_transport_a_free_1', 'gis_osm_transport_free_1', 'gis_osm_water_a_free_1', 'gis_osm_waterways_free_1'. Specify layer parameter to avoid this warning.
#   result = read_func(
#          name        type                                           geometry
# 0        None        None  POLYGON ((84.97782 56.51023, 84.97797 56.51033...
# 1        None  apartments  POLYGON ((84.97648 56.51430, 84.97719 56.51481...
# ...

# %%
south_district = read_shape_file('https://download.geofabrik.de/russia/south-fed-district-latest-free.shp.zip')
display(south_district)
# Out:
# /usr/local/lib/python3.10/dist-packages/pyogrio/geopandas.py:252: UserWarning: More than one layer found in 'south-fed-district-latest-free.shp.zip': 'gis_osm_buildings_a_free_1' (default), 'gis_osm_landuse_a_free_1', 'gis_osm_natural_a_free_1', 'gis_osm_natural_free_1', 'gis_osm_places_a_free_1', 'gis_osm_places_free_1', 'gis_osm_pofw_a_free_1', 'gis_osm_pofw_free_1', 'gis_osm_pois_a_free_1', 'gis_osm_pois_free_1', 'gis_osm_railways_free_1', 'gis_osm_roads_free_1', 'gis_osm_traffic_a_free_1', 'gis_osm_traffic_free_1', 'gis_osm_transport_a_free_1', 'gis_osm_transport_free_1', 'gis_osm_water_a_free_1', 'gis_osm_waterways_free_1'. Specify layer parameter to avoid this warning.
#   result = read_func(
#                         name        type  \
# 0                      Волна        None
# 1                       None  apartments
# 2        МЕГА Ростов-на-Дону       store
# 3                       None        None
# 4                       None  apartments
# ...

# %%
ural_district = read_shape_file('https://download.geofabrik.de/russia/ural-fed-district-latest-free.shp.zip')
display(ural_district)
# Out:
# /usr/local/lib/python3.10/dist-packages/pyogrio/geopandas.py:252: UserWarning: More than one layer found in 'ural-fed-district-latest-free.shp.zip': 'gis_osm_buildings_a_free_1' (default), 'gis_osm_landuse_a_free_1', 'gis_osm_natural_a_free_1', 'gis_osm_natural_free_1', 'gis_osm_places_a_free_1', 'gis_osm_places_free_1', 'gis_osm_pofw_a_free_1', 'gis_osm_pofw_free_1', 'gis_osm_pois_a_free_1', 'gis_osm_pois_free_1', 'gis_osm_railways_free_1', 'gis_osm_roads_free_1', 'gis_osm_traffic_a_free_1', 'gis_osm_traffic_free_1', 'gis_osm_transport_a_free_1', 'gis_osm_transport_free_1', 'gis_osm_water_a_free_1', 'gis_osm_waterways_free_1'. Specify layer parameter to avoid this warning.
#   result = read_func(
#                                                       name        type  \
# 0                                                     None      retail
# 1        Уральский федеральный университет имени первог...  university
# ...

# %%
volga_district = read_shape_file('https://download.geofabrik.de/russia/volga-fed-district-latest-free.shp.zip')
display(volga_district)
# Out:
# /usr/local/lib/python3.10/dist-packages/pyogrio/geopandas.py:252: UserWarning: More than one layer found in 'volga-fed-district-latest-free.shp.zip': 'gis_osm_buildings_a_free_1' (default), 'gis_osm_landuse_a_free_1', 'gis_osm_natural_a_free_1', 'gis_osm_natural_free_1', 'gis_osm_places_a_free_1', 'gis_osm_places_free_1', 'gis_osm_pofw_a_free_1', 'gis_osm_pofw_free_1', 'gis_osm_pois_a_free_1', 'gis_osm_pois_free_1', 'gis_osm_railways_free_1', 'gis_osm_roads_free_1', 'gis_osm_traffic_a_free_1', 'gis_osm_traffic_free_1', 'gis_osm_transport_a_free_1', 'gis_osm_transport_free_1', 'gis_osm_water_a_free_1', 'gis_osm_waterways_free_1'. Specify layer parameter to avoid this warning.
#   result = read_func(
#                          name        type  \
# 0                        None  apartments
# 1                        None    hospital
# 2                        None      public
# 3        Корпус 28А Оранжерея        None
# 4                        None        None
# ...

# %%
kaliningrad_district = read_shape_file('https://download.geofabrik.de/russia/kaliningrad-latest-free.shp.zip')
display(kaliningrad_district)
# Out:
# /usr/local/lib/python3.10/dist-packages/pyogrio/geopandas.py:252: UserWarning: More than one layer found in 'kaliningrad-latest-free.shp.zip': 'gis_osm_buildings_a_free_1' (default), 'gis_osm_landuse_a_free_1', 'gis_osm_natural_a_free_1', 'gis_osm_natural_free_1', 'gis_osm_places_a_free_1', 'gis_osm_places_free_1', 'gis_osm_pofw_a_free_1', 'gis_osm_pofw_free_1', 'gis_osm_pois_a_free_1', 'gis_osm_pois_free_1', 'gis_osm_railways_free_1', 'gis_osm_roads_free_1', 'gis_osm_traffic_a_free_1', 'gis_osm_traffic_free_1', 'gis_osm_transport_a_free_1', 'gis_osm_transport_free_1', 'gis_osm_water_a_free_1', 'gis_osm_waterways_free_1'. Specify layer parameter to avoid this warning.
#   result = read_func(
#                                                  name        type  \
# 0                                  Кафедральный собор   cathedral
# 1       Калининградский областной драматический театр       civic
# 2        Здание страхового общества "Северная звезда"       hotel
# ...

# %%
def find_objects(district, obj_type):
  df = district[district['type'] == obj_type]
  return df

# %%
central_military_objects = find_objects(central_district, 'military')
display(central_military_objects)
# Out:
#                                                       name      type  \
# 3481     Объединённый военный комиссариат Тушинского ра...  military
# 28779                                                 None  military
# 51375                                                 None  military
# 51376                                                 None  military
# 51403                                                 None  military
# ...                                                    ...       ...
# 5274600                                               None  military
# 5274601                                               None  military
# 5274602                                               None  military
# 5274603                                               None  military
# 5274605                                               None  military
#
#                                                   geometry
# 3481     POLYGON ((37.48063 55.80116, 37.48084 55.80135...
# ...

# %%
occupied_crimea_military_objects = find_objects(occupied_crimea, 'military')
display(occupied_crimea)
# Out:
#                name    type                                           geometry
# 0              None    None  POLYGON ((35.41496 45.32753, 35.41501 45.32758...
# 1              None    None  POLYGON ((35.41507 45.32777, 35.41517 45.32786...
# 2              None    None  POLYGON ((35.41229 45.33092, 35.41231 45.33094...
# 3              None    None  POLYGON ((33.71984 44.40865, 33.72014 44.40877...
# 4              None    None  POLYGON ((35.81833 45.42612, 35.81841 45.42613...
# ...             ...     ...                                                ...
# 350202         None    None  POLYGON ((34.09192 44.95256, 34.09222 44.95280...
# 350203         None    None  POLYGON ((34.09400 44.95082, 34.09412 44.95093...
# 350204         None    None  POLYGON ((34.09313 44.95099, 34.09321 44.95105...
# 350205         None    None  POLYGON ((34.09195 44.95217, 34.09216 44.95235...
# 350206  Wildberries  retail  POLYGON ((34.04318 44.93810, 34.04325 44.93810...
#
# ...

# %%
far_eastern_military_objects = find_objects(far_eastern_district, 'military')
display(far_eastern_military_objects)
# Out:
#                  name      type  \
# 6447             None  military
# 10862            None  military
# 10864            None  military
# 716522           None  military
# 905121           None  military
# 1085943          None  military
# 1085944          None  military
# 1131094  Охрана моста  military
# 1131096          None  military
#
#                                                   geometry
# 6447     POLYGON ((142.74976 46.94644, 142.74996 46.946...
# 10862    POLYGON ((142.74922 46.94711, 142.74939 46.947...
# 10864    POLYGON ((142.74973 46.94705, 142.74991 46.947...
# 716522   POLYGON ((158.55027 53.13375, 158.55042 53.133...
# 905121   POLYGON ((142.74977 46.94733, 142.74984 46.947...
# 1085943  POLYGON ((158.55005 53.13401, 158.55015 53.134...
# 1085944  POLYGON ((158.54895 53.13398, 158.54899 53.134...
# 1131094  POLYGON ((137.02149 50.47192, 137.02187 50.472...
# 1131096  MULTIPOLYGON (((137.02117 50.47211, 137.02121 ...

# %%
north_caucasus_military_objects = find_objects(north_caucasus_district, 'military')
display(north_caucasus_military_objects)
# Out:
#          name      type                                           geometry
# 77489    None  military  POLYGON ((42.98370 43.20634, 42.98385 43.20636...
# 77504    None  military  POLYGON ((42.98358 43.20646, 42.98372 43.20647...
# 77507    None  military  POLYGON ((42.98350 43.20636, 42.98365 43.20637...
# 130145   None  military  POLYGON ((42.53426 43.24849, 42.53429 43.24868...
# 130146   None  military  POLYGON ((42.53543 43.24826, 42.53549 43.24864...
# ...       ...       ...                                                ...
# 1508017  None  military  POLYGON ((44.55542 43.76716, 44.55542 43.76721...
# 1508018  None  military  POLYGON ((44.55785 43.76989, 44.55788 43.77006...
# 1508019  None  military  POLYGON ((44.55755 43.77026, 44.55756 43.77031...
# 1520457  None  military  POLYGON ((46.38258 41.90372, 46.38266 41.90376...
# 1522557  None  military  POLYGON ((43.57940 43.62511, 43.57948 43.62513...
#
# [307 rows x 3 columns]

# %%
northwestern_military_objects = find_objects(northwestern_district, 'military')
display(northwestern_military_objects)
# Out:
#                                             name      type  \
# 11544    Военный комиссариат Фрунзенского района  military
# 55107                           Старый военкомат  military
# 81371                                       None  military
# 81376                                       None  military
# 81380                                       None  military
# 93614                     сгоревший Дом Офицеров  military
# 93623                           Бывший госпиталь  military
# 93636                        Заброшенные казармы  military
# 93673                        сгоревшая Кочегарка  military
# 94898                                       None  military
# 94899                                       None  military
# 94901                                       None  military
# 94906                                       None  military
# 94907                                       None  military
# 94911                                       None  military
# ...

# %%
siberial_military_objects = find_objects(siberial_district, 'military')
display(siberial_military_objects)
# Out:
#                      name      type  \
# 376116   Коммандный пункт  military
# 748615               None  military
# 748616               None  military
# 878888               None  military
# 2516246              None  military
#
#                                                   geometry
# 376116   POLYGON ((83.20938 54.89333, 83.20941 54.89336...
# 748615   POLYGON ((74.32342 56.89968, 74.32365 56.89972...
# 748616   POLYGON ((74.31976 56.89903, 74.32082 56.89920...
# 878888   POLYGON ((74.32187 56.89915, 74.32247 56.89929...
# 2516246  POLYGON ((74.32129 56.89890, 74.32188 56.89903...

# %%
south_military_objects = find_objects(south_district, 'military')
display(south_military_objects)
# Out:
#          name      type                                           geometry
# 49907    None  military  POLYGON ((39.63640 47.26170, 39.64092 47.26346...
# 55238    None  military  POLYGON ((39.66360 47.26513, 39.66386 47.26516...
# 55242    None  military  POLYGON ((39.65726 47.26974, 39.65739 47.26980...
# 55247    None  military  POLYGON ((39.65691 47.26910, 39.65753 47.26934...
# 55250    None  military  POLYGON ((39.65669 47.26948, 39.65683 47.26953...
# ...       ...       ...                                                ...
# 2872460  None  military  POLYGON ((39.71053 47.05289, 39.71053 47.05295...
# 2872461  None  military  POLYGON ((39.71012 47.05277, 39.71012 47.05295...
# 2916573  None  military  POLYGON ((40.00757 48.27842, 40.00767 48.27845...
# 2916575  None  military  POLYGON ((40.00793 48.27852, 40.00831 48.27862...
# 2916576  None  military  POLYGON ((40.00814 48.27891, 40.00864 48.27892...
#
# [1310 rows x 3 columns]

# %%
ural_military_objects = find_objects(ural_district, 'military')
display(ural_military_objects)
# Out:
#                          name      type  \
# 393779   Караульное помещение  military
# 394025                   None  military
# 394030                   None  military
# 395678                   None  military
# 395681                   None  military
# 1879592                  None  military
# 1879593                  None  military
# 1879594                  None  military
# 1879595                  None  military
# 1879596                  None  military
# 1908413           Пост охраны  military
# 1941092  Караульное помещение  military
#
#                                                   geometry
# 393779   POLYGON ((60.11170 57.96638, 60.11175 57.96645...
# 394025   POLYGON ((60.07020 57.96717, 60.07040 57.96722...
# 394030   POLYGON ((60.06972 57.96672, 60.07063 57.96696...
# 395678   POLYGON ((60.06581 57.96595, 60.06609 57.96602...
# 395681   POLYGON ((60.06647 57.96626, 60.06686 57.96637...
# 1879592  POLYGON ((60.69382 57.07307, 60.69393 57.07316...
# ...

# %%
volga_military_objects = find_objects(volga_district, 'military')
display(volga_military_objects)
# Out:
#          name      type                                           geometry
# 258014   None  military  POLYGON ((53.37761 57.87585, 53.37780 57.87591...
# 401341   None  military  POLYGON ((49.30739 59.08499, 49.30801 59.08510...
# 611272   None  military  POLYGON ((49.61026 58.58076, 49.61067 58.58091...
# 1243295  None  military  POLYGON ((53.26917 57.86069, 53.26933 57.86136...
# 1243322  None  military  POLYGON ((53.26677 57.85884, 53.26684 57.85916...
# 1243346  None  military  POLYGON ((53.26726 57.85835, 53.26732 57.85863...
# 1243354  None  military  POLYGON ((53.27037 57.86018, 53.27061 57.86129...
# 1243356  None  military  POLYGON ((53.28312 57.85987, 53.28323 57.86039...
# 6113502  None  military  POLYGON ((45.99806 51.18737, 45.99806 51.18740...
# 6141309  None  military  POLYGON ((53.28248 57.86146, 53.28251 57.86164...
# 6141310  None  military  POLYGON ((53.28207 57.85993, 53.28218 57.86045...
# ...

# %%
kaliningrad_military_objects = find_objects(kaliningrad_district, 'military')
display(kaliningrad_military_objects)
# Out:
# Empty GeoDataFrame
# Columns: [name, type, geometry]
# Index: []

# %%
central_district_military_buildings = central_district[central_district['type'] == 'military']
central_district_street_map = folium.Map(location = [55.755863, 37.617700], zoom_start=6)
folium.GeoJson(central_district_military_buildings.geometry).add_to(central_district_street_map)
display(central_district_street_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
central_district_military_buildings['center'] = [x.geometry.centroid for i, x in central_district_military_buildings.iterrows()]
display(central_district_military_buildings)
# Out:
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#                                                       name      type  \
# 3481     Объединённый военный комиссариат Тушинского ра...  military
# 28779                                                 None  military
# 51375                                                 None  military
# 51376                                                 None  military
# 51403                                                 None  military
# ...                                                    ...       ...
# 5274600                                               None  military
# ...

# %%
central_district_military_buildings['location'] = [(row.center.y, row.center.x) for index, row in central_district_military_buildings.iterrows()]
central_district_military_buildings
# Out:
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#                                                       name      type  \
# 3481     Объединённый военный комиссариат Тушинского ра...  military
# 28779                                                 None  military
# 51375                                                 None  military
# 51376                                                 None  military
# 51403                                                 None  military
# ...                                                    ...       ...
# 5274600                                               None  military
# ...

# %%
for index, row in central_district_military_buildings.iterrows():
  location = [row['location'][0], row['location'][1]]
  popup = f"<strong>{row['name']}</strong>"
  marker = folium.Marker(location=location, popup=popup)
  marker.add_to(central_district_street_map)
display(central_district_street_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
kaliningrad_district = gpd.read_file('https://download.geofabrik.de/russia/kaliningrad-latest-free.shp.zip')

# %%
building_types_kaliningrad = kaliningrad_district['type'].unique()
display(building_types_kaliningrad)
kaliningrad_ships = kaliningrad_district[kaliningrad_district['type']=='ship']
display(kaliningrad_ships)
kaliningrad_transformer_tower = kaliningrad_district[kaliningrad_district['type']=='transformer_tower']
display(kaliningrad_transformer_tower)
kaliningrad_gasometers = kaliningrad_district[kaliningrad_district['type']=='gasometer']
display(kaliningrad_gasometers)
kaliningrad_manufacture = kaliningrad_district[kaliningrad_district['type']=='manufacture']
display(kaliningrad_manufacture)
kaliningrad_tower = kaliningrad_district[kaliningrad_district['type']=='tower']
display(kaliningrad_tower)
kaliningrad_industrial = kaliningrad_district[kaliningrad_district['type']=='industrial']
display(kaliningrad_industrial)
# Out:
# array(['cathedral', 'civic', 'hotel', 'retail', None, 'train_station',
#        'church', 'commercial', 'hangar', 'gatehouse', 'apartments',
#        'transportation', 'service', 'public', 'castle', 'roof', 'school',
#        'chapel', 'industrial', 'residential', 'office', 'dormitory',
#        'bus_station', 'kindergarten', 'house', 'university', 'hospital',
#        'garages', 'abandoned', 'semidetached_house', 'sports_centre',
#        'detached', 'college', 'terrace', 'warehouse', 'garage',
#        'agricultural', 'station', 'ruins', 'bunker', 'farm_auxiliary',
#        'shed', 'construction', 'brewery', 'transformer_tower', 'farm',
#        'kiosk', 'greenhouse', 'government', 'manufacture', 'stable',
#        'supermarket', 'ship', 'hut', 'barn', 'shelter', 'shop',
#        'collapsed', 'tower', 'grandstand', 'cabin', 'cowshed', 'carport',
#        'prison', 'gasometer', 'silo', 'outbuilding', 'storage_tank',
#        'pavilion', 'synagogue', 'yesm', 'temple', 'roof;yes',
# ...

# %%
kaliningrad_street_map = folium.Map(location = [54.715424, 20.509207], zoom_start=11)
folium.GeoJson(kaliningrad_industrial.geometry).add_to(kaliningrad_street_map)
display(kaliningrad_street_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
